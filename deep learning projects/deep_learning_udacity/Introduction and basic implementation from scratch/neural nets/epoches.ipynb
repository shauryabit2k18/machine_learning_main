# %%
import math

def batches(batch_size , features , labels):
    assert len(features) == len(labels)
    outout_batches = []
    
    sample_size = len(features)
    for start_i in range(0, sample_size, batch_size):
        end_i = start_i + batch_size
        batch = [features[start_i:end_i], labels[start_i:end_i]]
        outout_batches.append(batch)
        
    return outout_batches

# %%
import tensorflow as tf
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data

def print_epoch_stats(epoch_i , sess , last_features , last_labels):
    current_cost = sess.run(cost , feed_dict = {features:last_features , labels:last_labels})
    valid_accuracy = sess.run(accuracy , feed_dict = {features:valid_features , labels:valid_labels})
    print('epoch: {:<4} - cost: {:<8.3} valid accuracy: {:<5.3}'.format(epoch_i , current_cost , valid_accuracy))
    
n_input =784
n_classes = 10

mnist = input_data.read_data_sets('/datasets/ud730/mnist' , one_hot = True)

train_features = mnist.train.images
valid_features = mnist.validation.images
test_features = mnist.test.images

train_labels = mnist.train.labels.astype(np.float32)
valid_labels = mnist.validation.labels.astype(np.float32)
test_labels = mnist.test.labels.astype(np.float32)

features = tf.placeholder(tf.float32, [None, n_input])
labels = tf.placeholder(tf.float32, [None, n_classes])

weights = tf.Variable(tf.random_normal([n_input, n_classes]))
bias = tf.Variable(tf.random_normal([n_classes]))

logits = tf.add(tf.matmul(features, weights), bias)

learning_rate = tf.placeholder(tf.float32)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost)

correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

init = tf.global_variables_initializer()

batch_size = 128
epochs = 150
learn_rate = 0.001

train_batches = batches(batch_size, train_features, train_labels)

with tf.Session() as sess:
    sess.run(init)

    for epoch_i in range(epochs):
        for batch_features, batch_labels in train_batches:
            train_feed_dict = {features: batch_features , labels: batch_labels , learning_rate: learn_rate}
            sess.run(optimizer, feed_dict=train_feed_dict)
        
        print_epoch_stats(epoch_i , sess , batch_features , batch_labels)
    
    test_accuracy = sess.run(accuracy , feed_dict = {features:test_features , labels:test_labels})
    
print('test accuracy:{}'.format(test_accuracy))
# Out:
# Extracting /datasets/ud730/mnist\train-images-idx3-ubyte.gz
# Extracting /datasets/ud730/mnist\train-labels-idx1-ubyte.gz
# Extracting /datasets/ud730/mnist\t10k-images-idx3-ubyte.gz
# Extracting /datasets/ud730/mnist\t10k-labels-idx1-ubyte.gz
# epoch: 0    - cost: 12.2     valid accuracy: 0.0776
# epoch: 1    - cost: 11.0     valid accuracy: 0.0888
# epoch: 2    - cost: 10.3     valid accuracy: 0.0964
# epoch: 3    - cost: 9.71     valid accuracy: 0.108
# epoch: 4    - cost: 9.25     valid accuracy: 0.119
# epoch: 5    - cost: 8.84     valid accuracy: 0.132
# epoch: 6    - cost: 8.46     valid accuracy: 0.147
# epoch: 7    - cost: 8.09     valid accuracy: 0.163
# epoch: 8    - cost: 7.74     valid accuracy: 0.182
# epoch: 9    - cost: 7.4      valid accuracy: 0.201
# epoch: 10   - cost: 7.08     valid accuracy: 0.22
# epoch: 11   - cost: 6.78     valid accuracy: 0.24
# epoch: 12   - cost: 6.5      valid accuracy: 0.261
# epoch: 13   - cost: 6.23     valid accuracy: 0.278
# epoch: 14   - cost: 5.99     valid accuracy: 0.297
# epoch: 15   - cost: 5.76     valid accuracy: 0.316
# epoch: 16   - cost: 5.54     valid accuracy: 0.334
# epoch: 17   - cost: 5.34     valid accuracy: 0.351
# epoch: 18   - cost: 5.14     valid accuracy: 0.365
# epoch: 19   - cost: 4.96     valid accuracy: 0.381
# epoch: 20   - cost: 4.79     valid accuracy: 0.396
# epoch: 21   - cost: 4.63     valid accuracy: 0.41
# epoch: 22   - cost: 4.47     valid accuracy: 0.421
# epoch: 23   - cost: 4.33     valid accuracy: 0.436
# epoch: 24   - cost: 4.19     valid accuracy: 0.446
# epoch: 25   - cost: 4.07     valid accuracy: 0.458
# epoch: 26   - cost: 3.94     valid accuracy: 0.469
# epoch: 27   - cost: 3.83     valid accuracy: 0.478
# epoch: 28   - cost: 3.72     valid accuracy: 0.486
# epoch: 29   - cost: 3.62     valid accuracy: 0.495
# epoch: 30   - cost: 3.53     valid accuracy: 0.503
# epoch: 31   - cost: 3.44     valid accuracy: 0.51
# epoch: 32   - cost: 3.36     valid accuracy: 0.518
# epoch: 33   - cost: 3.28     valid accuracy: 0.526
# epoch: 34   - cost: 3.2      valid accuracy: 0.531
# epoch: 35   - cost: 3.13     valid accuracy: 0.538
# epoch: 36   - cost: 3.06     valid accuracy: 0.545
# epoch: 37   - cost: 3.0      valid accuracy: 0.552
# epoch: 38   - cost: 2.94     valid accuracy: 0.558
# epoch: 39   - cost: 2.88     valid accuracy: 0.564
# epoch: 40   - cost: 2.83     valid accuracy: 0.569
# epoch: 41   - cost: 2.77     valid accuracy: 0.575
# epoch: 42   - cost: 2.72     valid accuracy: 0.579
# epoch: 43   - cost: 2.68     valid accuracy: 0.585
# epoch: 44   - cost: 2.63     valid accuracy: 0.59
# epoch: 45   - cost: 2.59     valid accuracy: 0.594
# epoch: 46   - cost: 2.54     valid accuracy: 0.599
# epoch: 47   - cost: 2.5      valid accuracy: 0.604
# epoch: 48   - cost: 2.47     valid accuracy: 0.608
# epoch: 49   - cost: 2.43     valid accuracy: 0.612
# epoch: 50   - cost: 2.39     valid accuracy: 0.617
# epoch: 51   - cost: 2.36     valid accuracy: 0.622
# epoch: 52   - cost: 2.32     valid accuracy: 0.628
# epoch: 53   - cost: 2.29     valid accuracy: 0.632
# epoch: 54   - cost: 2.26     valid accuracy: 0.635
# epoch: 55   - cost: 2.23     valid accuracy: 0.64
# epoch: 56   - cost: 2.2      valid accuracy: 0.642
# epoch: 57   - cost: 2.17     valid accuracy: 0.645
# epoch: 58   - cost: 2.15     valid accuracy: 0.647
# epoch: 59   - cost: 2.12     valid accuracy: 0.65
# epoch: 60   - cost: 2.09     valid accuracy: 0.654
# epoch: 61   - cost: 2.07     valid accuracy: 0.656
# epoch: 62   - cost: 2.04     valid accuracy: 0.658
# epoch: 63   - cost: 2.02     valid accuracy: 0.661
# epoch: 64   - cost: 2.0      valid accuracy: 0.663
# epoch: 65   - cost: 1.98     valid accuracy: 0.665
# epoch: 66   - cost: 1.95     valid accuracy: 0.668
# epoch: 67   - cost: 1.93     valid accuracy: 0.67
# epoch: 68   - cost: 1.91     valid accuracy: 0.671
# epoch: 69   - cost: 1.89     valid accuracy: 0.673
# epoch: 70   - cost: 1.88     valid accuracy: 0.674
# epoch: 71   - cost: 1.86     valid accuracy: 0.676
# epoch: 72   - cost: 1.84     valid accuracy: 0.679
# epoch: 73   - cost: 1.82     valid accuracy: 0.68
# epoch: 74   - cost: 1.8      valid accuracy: 0.682
# epoch: 75   - cost: 1.79     valid accuracy: 0.684
# epoch: 76   - cost: 1.77     valid accuracy: 0.687
# epoch: 77   - cost: 1.75     valid accuracy: 0.689
# epoch: 78   - cost: 1.74     valid accuracy: 0.692
# epoch: 79   - cost: 1.72     valid accuracy: 0.694
# epoch: 80   - cost: 1.71     valid accuracy: 0.695
# epoch: 81   - cost: 1.69     valid accuracy: 0.697
# epoch: 82   - cost: 1.68     valid accuracy: 0.698
# epoch: 83   - cost: 1.67     valid accuracy: 0.7
# epoch: 84   - cost: 1.65     valid accuracy: 0.701
# epoch: 85   - cost: 1.64     valid accuracy: 0.703
# epoch: 86   - cost: 1.63     valid accuracy: 0.704
# epoch: 87   - cost: 1.61     valid accuracy: 0.706
# epoch: 88   - cost: 1.6      valid accuracy: 0.707
# epoch: 89   - cost: 1.59     valid accuracy: 0.71
# epoch: 90   - cost: 1.58     valid accuracy: 0.711
# epoch: 91   - cost: 1.57     valid accuracy: 0.712
# epoch: 92   - cost: 1.56     valid accuracy: 0.713
# epoch: 93   - cost: 1.54     valid accuracy: 0.716
# epoch: 94   - cost: 1.53     valid accuracy: 0.718
# epoch: 95   - cost: 1.52     valid accuracy: 0.719
# epoch: 96   - cost: 1.51     valid accuracy: 0.721
# epoch: 97   - cost: 1.5      valid accuracy: 0.723
# epoch: 98   - cost: 1.49     valid accuracy: 0.724
# epoch: 99   - cost: 1.48     valid accuracy: 0.727
# epoch: 100  - cost: 1.47     valid accuracy: 0.728
# epoch: 101  - cost: 1.46     valid accuracy: 0.73
# epoch: 102  - cost: 1.45     valid accuracy: 0.731
# epoch: 103  - cost: 1.45     valid accuracy: 0.732
# epoch: 104  - cost: 1.44     valid accuracy: 0.733
# epoch: 105  - cost: 1.43     valid accuracy: 0.734
# epoch: 106  - cost: 1.42     valid accuracy: 0.735
# epoch: 107  - cost: 1.41     valid accuracy: 0.737
# epoch: 108  - cost: 1.4      valid accuracy: 0.739
# epoch: 109  - cost: 1.4      valid accuracy: 0.739
# epoch: 110  - cost: 1.39     valid accuracy: 0.741
# epoch: 111  - cost: 1.38     valid accuracy: 0.741
# epoch: 112  - cost: 1.37     valid accuracy: 0.743
# epoch: 113  - cost: 1.36     valid accuracy: 0.743
# epoch: 114  - cost: 1.36     valid accuracy: 0.744
# epoch: 115  - cost: 1.35     valid accuracy: 0.744
# epoch: 116  - cost: 1.34     valid accuracy: 0.745
# epoch: 117  - cost: 1.34     valid accuracy: 0.747
# epoch: 118  - cost: 1.33     valid accuracy: 0.748
# epoch: 119  - cost: 1.32     valid accuracy: 0.749
# epoch: 120  - cost: 1.32     valid accuracy: 0.749
# epoch: 121  - cost: 1.31     valid accuracy: 0.75
# epoch: 122  - cost: 1.3      valid accuracy: 0.751
# epoch: 123  - cost: 1.3      valid accuracy: 0.752
# epoch: 124  - cost: 1.29     valid accuracy: 0.754
# epoch: 125  - cost: 1.28     valid accuracy: 0.754
# epoch: 126  - cost: 1.28     valid accuracy: 0.755
# epoch: 127  - cost: 1.27     valid accuracy: 0.755
# epoch: 128  - cost: 1.27     valid accuracy: 0.756
# epoch: 129  - cost: 1.26     valid accuracy: 0.756
# epoch: 130  - cost: 1.26     valid accuracy: 0.757
# epoch: 131  - cost: 1.25     valid accuracy: 0.758
# epoch: 132  - cost: 1.25     valid accuracy: 0.758
# epoch: 133  - cost: 1.24     valid accuracy: 0.759
# epoch: 134  - cost: 1.23     valid accuracy: 0.759
# epoch: 135  - cost: 1.23     valid accuracy: 0.76
# epoch: 136  - cost: 1.22     valid accuracy: 0.761
# epoch: 137  - cost: 1.22     valid accuracy: 0.761
# epoch: 138  - cost: 1.21     valid accuracy: 0.762
# epoch: 139  - cost: 1.21     valid accuracy: 0.763
# epoch: 140  - cost: 1.2      valid accuracy: 0.764
# epoch: 141  - cost: 1.2      valid accuracy: 0.764
# epoch: 142  - cost: 1.2      valid accuracy: 0.765
# epoch: 143  - cost: 1.19     valid accuracy: 0.766
# epoch: 144  - cost: 1.19     valid accuracy: 0.767
# epoch: 145  - cost: 1.18     valid accuracy: 0.767
# epoch: 146  - cost: 1.18     valid accuracy: 0.768
# epoch: 147  - cost: 1.17     valid accuracy: 0.768
# epoch: 148  - cost: 1.17     valid accuracy: 0.768
# epoch: 149  - cost: 1.16     valid accuracy: 0.769
# test accuracy:0.7682999968528748
